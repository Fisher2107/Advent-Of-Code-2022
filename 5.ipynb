# %%
with open('5.txt', 'r') as f:
    data = f.read().splitlines()
del data[:10]
A1="DHNQTWVB"
A2="DWB"
A3="TSQWJC"
A4="FJRNZTP"
A5="GPVJMST"
A6="BWFTN"
A7="BLDQFHVN"
A8="HPFR"
A9="ZSMBLNPH"
for i in range(len(data)):
    data[i]=(int(data[i][5 if data[i].index(" from")-1 == 5 else 5:7]),int(data[i][data[i].index(" to")-1]),int(data[i][-1]))
    #origin=globals()[f"A{data[i][1]}"]
    #destination=globals()[f"A{data[i][2]}"]
    #print(data[i])
    for j in range(data[i][0]):
        remove=globals()[f"A{data[i][1]}"][-1]
        globals()[f"A{data[i][1]}"]=globals()[f"A{data[i][1]}"][:-1]
        globals()[f"A{data[i][2]}"]=globals()[f"A{data[i][2]}"]+remove
    #print(A1,A2,A3,A4,A5,A6,A7,A8,A9)

def last(a):
    return a[-1]

"".join(list(map(last,(A1,A2,A3,A4,A5,A6,A7,A8,A9))))
# Out:
# 'PSNRGBTFT'

# %%
with open('5.txt', 'r') as f:
    data = f.read().splitlines()
del data[:10]
A1="DHNQTWVB"
A2="DWB"
A3="TSQWJC"
A4="FJRNZTP"
A5="GPVJMST"
A6="BWFTN"
A7="BLDQFHVN"
A8="HPFR"
A9="ZSMBLNPH"
for i in range(len(data)):
    data[i]=(int(data[i][5 if data[i].index(" from")-1 == 5 else 5:7]),int(data[i][data[i].index(" to")-1]),int(data[i][-1]))
    #origin=globals()[f"A{data[i][1]}"]
    #destination=globals()[f"A{data[i][2]}"]
    #print(data[i])
    amount = data[i][0]
    remove=globals()[f"A{data[i][1]}"][-amount-1:-1]
    print(remove)
    globals()[f"A{data[i][1]}"]=globals()[f"A{data[i][1]}"][:-len(remove)]
    globals()[f"A{data[i][2]}"]=globals()[f"A{data[i][2]}"]+remove
    print(A1,A2,A3,A4,A5,A6,A7,A8,A9)

def last(a):
    return a[-1]

"".join(list(map(last,(A1,A2,A3,A4,A5,A6,A7,A8,A9))))
# Out:
# PF
# DHNQTWVBPF DWB TSQWJC FJRNZTP GPVJMST BWFTN BLDQFHVN HP ZSMBLNPH
# BLNP
# DHNQTWVBPF DWB TSQWJC FJRNZTP GPVJMST BWFTN BLDQFHVN HPBLNP ZSMB
# BP
# DHNQTWVB DWB TSQWJC FJRNZTP GPVJMST BWFTNBP BLDQFHVN HPBLNP ZSMB
# FJRNZT
# DHNQTWVB DWBFJRNZT TSQWJC F GPVJMST BWFTNBP BLDQFHVN HPBLNP ZSMB
# DWBFJRNZ
# DHNQTWVB D TSQWJC F GPVJMST BWFTNBP BLDQFHVNDWBFJRNZ HPBLNP ZSMB
# WV
# DHNQTW D TSQWJC F GPVJMST BWFTNBPWV BLDQFHVNDWBFJRNZ HPBLNP ZSMB
# M
# DHNQTW D TSQWJC FM GPVJMST BWFTNBPWV BLDQFHVNDWBFJRNZ HPBLNP ZSM
# F
# DHNQTWF D TSQWJC F GPVJMST BWFTNBPWV BLDQFHVNDWBFJRNZ HPBLNP ZSM
# BWFTNBPW
# DHNQTWF D TSQWJC FBWFTNBPW GPVJMST B BLDQFHVNDWBFJRNZ HPBLNP ZSM
# DHNQTW
# D D TSQWJC FBWFTNBPW GPVJMST B BLDQFHVNDWBFJRNZ HPBLNPDHNQTW ZSM
# PDHNQT
# DPDHNQT D TSQWJC FBWFTNBPW GPVJMST B BLDQFHVNDWBFJRNZ HPBLNP ZSM
# P
# DPDHNQTP D TSQWJC FBWFTNBP GPVJMST B BLDQFHVNDWBFJRNZ HPBLNP ZSM
# NDWBFJRN
# DPDHNQTP D TSQWJCNDWBFJRN FBWFTNBP GPVJMST B BLDQFHVN HPBLNP ZSM
# MS
# ...
